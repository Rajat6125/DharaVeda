# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
data=pd.read_csv(r"Dataset\fertilizer_recommendation.csv")

# %%
data.columns
# Out:
# Index(['Soil_Type', 'Soil_pH', 'Soil_Moisture', 'Organic_Carbon',
#        'Electrical_Conductivity', 'Nitrogen_Level', 'Phosphorus_Level',
#        'Potassium_Level', 'Temperature', 'Humidity', 'Rainfall', 'Crop_Type',
#        'Crop_Growth_Stage', 'Season', 'Irrigation_Type', 'Previous_Crop',
#        'Region', 'Fertilizer_Used_Last_Season', 'Yield_Last_Season',
#        'Recommended_Fertilizer'],
#       dtype='object')

# %%
data['Soil_Type'].value_counts()
# Out:
# Soil_Type
# Clay     20116
# Loamy    20048
# Silt     19975
# Sandy    19861
# Name: count, dtype: int64

# %%
X=data[['Soil_Type','Soil_pH','Soil_Moisture','Organic_Carbon','Nitrogen_Level','Phosphorus_Level','Potassium_Level','Temperature','Humidity','Rainfall','Crop_Type','Crop_Growth_Stage','Season','Previous_Crop']]
y=data['Recommended_Fertilizer']

# %%
# X['Soil_Type'].unique()
# X['Soil_Type'].unique()
# X['Crop_Type'].unique()
# X['Crop_Growth_Stage'].unique()
X['Season'].unique()
# X['Previous_Crop'].unique()
# Out:
# array(['Zaid', 'Kharif', 'Rabi'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder(
    categories=[
        # Soil_Type (automatic order)
        sorted(X["Soil_Type"].unique()),

        # Crop_Type (automatic order)
        sorted(X["Crop_Type"].unique()),

        # Crop_Growth_Stage (logical order)
        ["Sowing", "Vegetative", "Flowering", "Harvest"],

        # Season (your desired order)
        ["Kharif", "Rabi", "Zaid"],

        # Previous_Crop (automatic order)
        sorted(X["Previous_Crop"].unique())
    ]
)

cat_cols = [
    "Soil_Type",
    "Crop_Type",
    "Crop_Growth_Stage",
    "Season",
    "Previous_Crop"
]

X[cat_cols] = encoder.fit_transform(X[cat_cols])
# Out:
# C:\Users\rajat\AppData\Local\Temp\ipykernel_20840\3427134729.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[cat_cols] = encoder.fit_transform(X[cat_cols])

# %%
X
# Out:
#        Soil_Type  Soil_pH  ...  Season  Previous_Crop
# 0            1.0     7.31  ...     2.0            6.0
# 1            2.0     7.13  ...     0.0            3.0
# 2            2.0     5.19  ...     1.0            6.0
# 3            1.0     5.54  ...     2.0            6.0
# 4            0.0     5.66  ...     2.0            3.0
# ...          ...      ...  ...     ...            ...
# 79995        0.0     8.08  ...     1.0            5.0
# 79996        1.0     7.98  ...     0.0            0.0
# 79997        2.0     5.70  ...     0.0            3.0
# 79998        3.0     6.32  ...     2.0            4.0
# 79999        0.0     6.15  ...     0.0            3.0
#
# [80000 rows x 14 columns]

# %%
from sklearn.preprocessing import LabelEncoder

target_encoder = LabelEncoder()

y = target_encoder.fit_transform(y)

# %%
y
# Out:
# array([0, 0, 4, ..., 4, 3, 5], shape=(80000,))

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %%
model=XGBClassifier(n_estimators=200,learning_rate=0.1,max_depth=6)
model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
train=model.predict(X_train)

# %%
accuracy_score(y_train,train)
# Out:
# 0.917828125

# %%
print(classification_report(y_train,train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90      8779
#            1       0.90      0.87      0.88     10410
#            2       0.96      0.96      0.96      9133
#            3       0.88      0.93      0.90      8503
#            4       0.89      0.92      0.90      8107
#            5       0.96      0.91      0.93     10503
#            6       0.94      0.96      0.95      8565
#
#     accuracy                           0.92     64000
#    macro avg       0.92      0.92      0.92     64000
# weighted avg       0.92      0.92      0.92     64000

# %%
test=model.predict(X_test)

# %%
accuracy_score(y_test,test)
# Out:
# 0.8695

# %%
print(classification_report(y_test,test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.82      0.81      2207
#            1       0.84      0.81      0.83      2537
#            2       0.93      0.93      0.93      2241
#            3       0.81      0.86      0.84      2146
#            4       0.85      0.87      0.86      2053
#            5       0.93      0.86      0.89      2618
#            6       0.91      0.94      0.93      2198
#
#     accuracy                           0.87     16000
#    macro avg       0.87      0.87      0.87     16000
# weighted avg       0.87      0.87      0.87     16000

# %%
import pandas as pd

sample = pd.DataFrame({
    "Soil_Type": ["Loamy"],
    "Soil_pH": [6.7],
    "Soil_Moisture": [38],
    "Organic_Carbon": [0.7],
    "Nitrogen_Level": [22],
    "Phosphorus_Level": [55],
    "Potassium_Level": [85],
    "Temperature": [29],
    "Humidity": [75],
    "Rainfall": [150],
    "Crop_Type": ["Rice"],
    "Crop_Growth_Stage": ["Vegetative"],
    "Season": ["Kharif"],
    "Previous_Crop": ["Wheat"]
})
sample[cat_cols] = encoder.transform(sample[cat_cols])
prediction=model.predict(sample)

# %%
fertilizer = target_encoder.inverse_transform(prediction)

print(fertilizer)
# Out:
# ['Urea']

# %%
probabilities = model.predict_proba(sample)
print("Prediction:", prediction[0])
print("Confidence:", probabilities.max())
# Out:
# Prediction: 5
# Confidence: 0.95331365
